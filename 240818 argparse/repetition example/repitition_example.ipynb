# %%
no = 1
seeds = [7,1234,42,13,80]
learning_rates = [0.1,0.01]

for lr in learning_rates :
    for seed in seeds :
        # !python repitition_example.py --no {no} \
                                      --seed {seed} \
                                      --lr {lr}
        no += 1
# Out:
# [1/10] Loss : 0.7699
# [2/10] Loss : 0.5216
# [3/10] Loss : 0.3058
# [4/10] Loss : 0.2058
# [5/10] Loss : 0.1931
# [6/10] Loss : 0.2828
# [7/10] Loss : 0.1259
# [8/10] Loss : 0.3071
# [9/10] Loss : 0.1695
# [10/10] Loss : 0.1412
#
# Setting
# Seed : 7, LR : 0.1
# Acc : 0.8333
# 1 Done
#
# [1/10] Loss : 1.0153
# [2/10] Loss : 0.6204
# [3/10] Loss : 0.4697
# [4/10] Loss : 0.5486
# [5/10] Loss : 0.3668
# [6/10] Loss : 0.3014
# [7/10] Loss : 0.3347
# [8/10] Loss : 0.3862
# [9/10] Loss : 0.2107
# [10/10] Loss : 0.1924
#
# Setting
# Seed : 1234, LR : 0.1
# Acc : 1.0000
# 2 Done
#
# [1/10] Loss : 1.9358
# [2/10] Loss : 0.8185
# [3/10] Loss : 0.6878
# [4/10] Loss : 0.4301
# [5/10] Loss : 0.4206
# [6/10] Loss : 0.4445
# [7/10] Loss : 0.2424
# [8/10] Loss : 0.1801
# [9/10] Loss : 0.3415
# [10/10] Loss : 0.0950
#
# Setting
# Seed : 42, LR : 0.1
# Acc : 0.9333
# 3 Done
#
# [1/10] Loss : 0.9751
# [2/10] Loss : 0.8636
# [3/10] Loss : 0.4960
# [4/10] Loss : 0.4302
# [5/10] Loss : 0.1519
# ...
